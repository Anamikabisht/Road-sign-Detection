# %% [markdown]
# <a href="https://colab.research.google.com/github/Anamikabisht/Road-sign-Detection/blob/main/RoadSignDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.2

# %% [markdown]
# Import dataset from roboflow

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection  sample_data

# %%
# %pwd
# Out:
# '/content'

# %%
import os
os.chdir('/content/RoadSignDetection')          #change directory
# %pwd
# Out:
# '/content/RoadSignDetection'

# %% [markdown]
# Train Yolov8 over a custom Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kC4JqDQx70nOf5cfNZI5")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:01<00:00, 5725.40it/s]

# %%
import os
os.chdir('/content/RoadSignDetection/Self-Driving-Cars-6')

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 271MB/s]
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py:341: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# Display some contents we obtained

# %%
# !ls "/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train"

# %%
from IPython.display import Image,display

Image("/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/confusion_matrix.png", width=600)

# %%
result = "/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train2/"
display(Image(filename=f'{result}results.png'))

# %%
import pandas as pd
df=pd.read_csv(f'{result}results.csv')
print(df.head())

# %%
display(Image(filename=f'{result}R_curve.png'))

# %%
display(Image(filename=f'{result}F1_curve.png'))

# %%
print(df.tail(1))

# %%
# %pwd #shows present dir

# %%
#change directory
os.chdir("/content")

# %%
# !mkdir myTestingData

# %%
os.chdir("/content/myTestingData")

# %%
weightsPath="/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source="road1.jpg" save=True

# %%
weightsPath="/content/RoadSignDetection/Traffic-signs-1/runs/detect/train3/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source="r1.jpeg" save=True

# %%
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source="road1.jpg" save=True

# %%
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source="road4vid.mp4" save=True
